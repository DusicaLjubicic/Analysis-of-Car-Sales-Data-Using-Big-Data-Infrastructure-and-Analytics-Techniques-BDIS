# %% [markdown]
# We start by importing the necessary libraries

# %%
from pymongo import MongoClient
import configparser
from pathlib import Path

# %% [markdown]
# Using the config parser, we access our configuration file, which contains the MongoDB URI, database name, and collection name.

# %%
config = configparser.ConfigParser()
config.read("../settings.cfg")

MONGO_URI = config.get("MONGO", "mongo_uri")
DB_NAME = config.get("MONGO", "database")
COLLECTION_NAME = config.get("MONGO", "collection")

# %% [markdown]
# After extracting these values, we connect to our local MongoDB instance and the specified database and collection using the Mongo client.

# %%
client = MongoClient(MONGO_URI)
db = client[DB_NAME]
collection = db[COLLECTION_NAME]

# %% [markdown]
# We then load the cleaned dataset.

# %%
import pandas as pd

df = pd.read_csv("../data/processed/car_sales_cleaned.csv")
print(df.shape)
# Out:
# (2500000, 11)

# %% [markdown]
# Since it contains 2.5 million records, it’s best to divide it into 250 batches of 10,000 records each. This approach ensures that all data is safely and efficiently inserted into the collection.

# %%
batch_size = 10000
total = len(df)

for i in range(0, total, batch_size):
    batch_df = df.iloc[i:i+batch_size]
    records = batch_df.to_dict(orient="records")
    collection.insert_many(records)
    print(f"Inserted {i+len(records)} out of {total} documents")
# Out:
# Inserted 10000 out of 2500000 documents
# Inserted 20000 out of 2500000 documents
# Inserted 30000 out of 2500000 documents
# Inserted 40000 out of 2500000 documents
# Inserted 50000 out of 2500000 documents
# Inserted 60000 out of 2500000 documents
# Inserted 70000 out of 2500000 documents
# Inserted 80000 out of 2500000 documents
# Inserted 90000 out of 2500000 documents
# Inserted 100000 out of 2500000 documents
# Inserted 110000 out of 2500000 documents
# Inserted 120000 out of 2500000 documents
# Inserted 130000 out of 2500000 documents
# Inserted 140000 out of 2500000 documents
# Inserted 150000 out of 2500000 documents
# Inserted 160000 out of 2500000 documents
# Inserted 170000 out of 2500000 documents
# Inserted 180000 out of 2500000 documents
# Inserted 190000 out of 2500000 documents
# Inserted 200000 out of 2500000 documents
# Inserted 210000 out of 2500000 documents
# Inserted 220000 out of 2500000 documents
# Inserted 230000 out of 2500000 documents
# Inserted 240000 out of 2500000 documents
# Inserted 250000 out of 2500000 documents
# Inserted 260000 out of 2500000 documents
# Inserted 270000 out of 2500000 documents
# Inserted 280000 out of 2500000 documents
# Inserted 290000 out of 2500000 documents
# Inserted 300000 out of 2500000 documents
# Inserted 310000 out of 2500000 documents
# Inserted 320000 out of 2500000 documents
# Inserted 330000 out of 2500000 documents
# Inserted 340000 out of 2500000 documents
# Inserted 350000 out of 2500000 documents
# Inserted 360000 out of 2500000 documents
# Inserted 370000 out of 2500000 documents
# Inserted 380000 out of 2500000 documents
# Inserted 390000 out of 2500000 documents
# Inserted 400000 out of 2500000 documents
# Inserted 410000 out of 2500000 documents
# Inserted 420000 out of 2500000 documents
# Inserted 430000 out of 2500000 documents
# Inserted 440000 out of 2500000 documents
# Inserted 450000 out of 2500000 documents
# Inserted 460000 out of 2500000 documents
# Inserted 470000 out of 2500000 documents
# Inserted 480000 out of 2500000 documents
# Inserted 490000 out of 2500000 documents
# Inserted 500000 out of 2500000 documents
# Inserted 510000 out of 2500000 documents
# Inserted 520000 out of 2500000 documents
# Inserted 530000 out of 2500000 documents
# Inserted 540000 out of 2500000 documents
# Inserted 550000 out of 2500000 documents
# Inserted 560000 out of 2500000 documents
# Inserted 570000 out of 2500000 documents
# Inserted 580000 out of 2500000 documents
# Inserted 590000 out of 2500000 documents
# Inserted 600000 out of 2500000 documents
# Inserted 610000 out of 2500000 documents
# Inserted 620000 out of 2500000 documents
# Inserted 630000 out of 2500000 documents
# Inserted 640000 out of 2500000 documents
# Inserted 650000 out of 2500000 documents
# Inserted 660000 out of 2500000 documents
# Inserted 670000 out of 2500000 documents
# Inserted 680000 out of 2500000 documents
# Inserted 690000 out of 2500000 documents
# Inserted 700000 out of 2500000 documents
# Inserted 710000 out of 2500000 documents
# Inserted 720000 out of 2500000 documents
# Inserted 730000 out of 2500000 documents
# Inserted 740000 out of 2500000 documents
# Inserted 750000 out of 2500000 documents
# Inserted 760000 out of 2500000 documents
# Inserted 770000 out of 2500000 documents
# Inserted 780000 out of 2500000 documents
# Inserted 790000 out of 2500000 documents
# Inserted 800000 out of 2500000 documents
# Inserted 810000 out of 2500000 documents
# Inserted 820000 out of 2500000 documents
# Inserted 830000 out of 2500000 documents
# Inserted 840000 out of 2500000 documents
# Inserted 850000 out of 2500000 documents
# Inserted 860000 out of 2500000 documents
# Inserted 870000 out of 2500000 documents
# Inserted 880000 out of 2500000 documents
# Inserted 890000 out of 2500000 documents
# Inserted 900000 out of 2500000 documents
# Inserted 910000 out of 2500000 documents
# Inserted 920000 out of 2500000 documents
# Inserted 930000 out of 2500000 documents
# Inserted 940000 out of 2500000 documents
# Inserted 950000 out of 2500000 documents
# Inserted 960000 out of 2500000 documents
# Inserted 970000 out of 2500000 documents
# Inserted 980000 out of 2500000 documents
# Inserted 990000 out of 2500000 documents
# Inserted 1000000 out of 2500000 documents
# Inserted 1010000 out of 2500000 documents
# Inserted 1020000 out of 2500000 documents
# Inserted 1030000 out of 2500000 documents
# Inserted 1040000 out of 2500000 documents
# Inserted 1050000 out of 2500000 documents
# Inserted 1060000 out of 2500000 documents
# Inserted 1070000 out of 2500000 documents
# Inserted 1080000 out of 2500000 documents
# Inserted 1090000 out of 2500000 documents
# Inserted 1100000 out of 2500000 documents
# Inserted 1110000 out of 2500000 documents
# Inserted 1120000 out of 2500000 documents
# Inserted 1130000 out of 2500000 documents
# Inserted 1140000 out of 2500000 documents
# Inserted 1150000 out of 2500000 documents
# Inserted 1160000 out of 2500000 documents
# Inserted 1170000 out of 2500000 documents
# Inserted 1180000 out of 2500000 documents
# Inserted 1190000 out of 2500000 documents
# Inserted 1200000 out of 2500000 documents
# Inserted 1210000 out of 2500000 documents
# Inserted 1220000 out of 2500000 documents
# Inserted 1230000 out of 2500000 documents
# Inserted 1240000 out of 2500000 documents
# Inserted 1250000 out of 2500000 documents
# Inserted 1260000 out of 2500000 documents
# Inserted 1270000 out of 2500000 documents
# Inserted 1280000 out of 2500000 documents
# Inserted 1290000 out of 2500000 documents
# Inserted 1300000 out of 2500000 documents
# Inserted 1310000 out of 2500000 documents
# Inserted 1320000 out of 2500000 documents
# Inserted 1330000 out of 2500000 documents
# Inserted 1340000 out of 2500000 documents
# Inserted 1350000 out of 2500000 documents
# Inserted 1360000 out of 2500000 documents
# Inserted 1370000 out of 2500000 documents
# Inserted 1380000 out of 2500000 documents
# Inserted 1390000 out of 2500000 documents
# Inserted 1400000 out of 2500000 documents
# Inserted 1410000 out of 2500000 documents
# Inserted 1420000 out of 2500000 documents
# Inserted 1430000 out of 2500000 documents
# Inserted 1440000 out of 2500000 documents
# Inserted 1450000 out of 2500000 documents
# Inserted 1460000 out of 2500000 documents
# Inserted 1470000 out of 2500000 documents
# Inserted 1480000 out of 2500000 documents
# Inserted 1490000 out of 2500000 documents
# Inserted 1500000 out of 2500000 documents
# Inserted 1510000 out of 2500000 documents
# Inserted 1520000 out of 2500000 documents
# Inserted 1530000 out of 2500000 documents
# Inserted 1540000 out of 2500000 documents
# Inserted 1550000 out of 2500000 documents
# Inserted 1560000 out of 2500000 documents
# Inserted 1570000 out of 2500000 documents
# Inserted 1580000 out of 2500000 documents
# Inserted 1590000 out of 2500000 documents
# Inserted 1600000 out of 2500000 documents
# Inserted 1610000 out of 2500000 documents
# Inserted 1620000 out of 2500000 documents
# Inserted 1630000 out of 2500000 documents
# Inserted 1640000 out of 2500000 documents
# Inserted 1650000 out of 2500000 documents
# Inserted 1660000 out of 2500000 documents
# Inserted 1670000 out of 2500000 documents
# Inserted 1680000 out of 2500000 documents
# Inserted 1690000 out of 2500000 documents
# Inserted 1700000 out of 2500000 documents
# Inserted 1710000 out of 2500000 documents
# Inserted 1720000 out of 2500000 documents
# Inserted 1730000 out of 2500000 documents
# Inserted 1740000 out of 2500000 documents
# Inserted 1750000 out of 2500000 documents
# Inserted 1760000 out of 2500000 documents
# Inserted 1770000 out of 2500000 documents
# Inserted 1780000 out of 2500000 documents
# Inserted 1790000 out of 2500000 documents
# Inserted 1800000 out of 2500000 documents
# Inserted 1810000 out of 2500000 documents
# Inserted 1820000 out of 2500000 documents
# Inserted 1830000 out of 2500000 documents
# Inserted 1840000 out of 2500000 documents
# Inserted 1850000 out of 2500000 documents
# Inserted 1860000 out of 2500000 documents
# Inserted 1870000 out of 2500000 documents
# Inserted 1880000 out of 2500000 documents
# Inserted 1890000 out of 2500000 documents
# Inserted 1900000 out of 2500000 documents
# Inserted 1910000 out of 2500000 documents
# Inserted 1920000 out of 2500000 documents
# Inserted 1930000 out of 2500000 documents
# Inserted 1940000 out of 2500000 documents
# Inserted 1950000 out of 2500000 documents
# Inserted 1960000 out of 2500000 documents
# Inserted 1970000 out of 2500000 documents
# Inserted 1980000 out of 2500000 documents
# Inserted 1990000 out of 2500000 documents
# Inserted 2000000 out of 2500000 documents
# Inserted 2010000 out of 2500000 documents
# Inserted 2020000 out of 2500000 documents
# Inserted 2030000 out of 2500000 documents
# Inserted 2040000 out of 2500000 documents
# Inserted 2050000 out of 2500000 documents
# Inserted 2060000 out of 2500000 documents
# Inserted 2070000 out of 2500000 documents
# Inserted 2080000 out of 2500000 documents
# Inserted 2090000 out of 2500000 documents
# Inserted 2100000 out of 2500000 documents
# Inserted 2110000 out of 2500000 documents
# Inserted 2120000 out of 2500000 documents
# Inserted 2130000 out of 2500000 documents
# Inserted 2140000 out of 2500000 documents
# Inserted 2150000 out of 2500000 documents
# Inserted 2160000 out of 2500000 documents
# Inserted 2170000 out of 2500000 documents
# Inserted 2180000 out of 2500000 documents
# Inserted 2190000 out of 2500000 documents
# Inserted 2200000 out of 2500000 documents
# Inserted 2210000 out of 2500000 documents
# Inserted 2220000 out of 2500000 documents
# Inserted 2230000 out of 2500000 documents
# Inserted 2240000 out of 2500000 documents
# Inserted 2250000 out of 2500000 documents
# Inserted 2260000 out of 2500000 documents
# Inserted 2270000 out of 2500000 documents
# Inserted 2280000 out of 2500000 documents
# Inserted 2290000 out of 2500000 documents
# Inserted 2300000 out of 2500000 documents
# Inserted 2310000 out of 2500000 documents
# Inserted 2320000 out of 2500000 documents
# Inserted 2330000 out of 2500000 documents
# Inserted 2340000 out of 2500000 documents
# Inserted 2350000 out of 2500000 documents
# Inserted 2360000 out of 2500000 documents
# Inserted 2370000 out of 2500000 documents
# Inserted 2380000 out of 2500000 documents
# Inserted 2390000 out of 2500000 documents
# Inserted 2400000 out of 2500000 documents
# Inserted 2410000 out of 2500000 documents
# Inserted 2420000 out of 2500000 documents
# Inserted 2430000 out of 2500000 documents
# Inserted 2440000 out of 2500000 documents
# Inserted 2450000 out of 2500000 documents
# Inserted 2460000 out of 2500000 documents
# Inserted 2470000 out of 2500000 documents
# Inserted 2480000 out of 2500000 documents
# Inserted 2490000 out of 2500000 documents
# Inserted 2500000 out of 2500000 documents

# %% [markdown]
# All data is safely inserted into the collection.
